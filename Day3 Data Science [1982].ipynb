# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %%
x=np.array([3,13,19,31,38,45,58,65,71,88])
y=np.array([11,16,24,37,41,58,56,78,81,95])
z=np.array([81,80,79,63,54,32,29,26,18,14])

# %%
plt.title('My First Plot')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.xlim(0,100)
plt.ylim(0,100)
plt.xticks(range(0,101,10))
plt.yticks(range(0,101,10))
plt.plot(x,y)

# %%
plt.title('My First Plot')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.xlim(0,100)
plt.ylim(0,100)
plt.xticks(range(0,101,10))
plt.yticks(range(0,101,10))
plt.plot(x,z)

# %%
plt.title('My First Plot')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.plot(x,y,color='purple',marker='o',ls=':',mfc='green')

# %%
plt.title('My First Plot')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.plot(x,y,color='brown',marker='*',ls=':',mfc='red')

# %%
plt.subplot(2,1,1)
plt.plot(x,y)
plt.subplot(2,1,2)
plt.plot(x,z)
plt.plot(x,y,color='purple',label='2023')
plt.plot(x,z,color='red',label='2022')
plt.legend()

# %%
plt.subplot(2,1,1)
plt.plot(x,y)

# %%
plt.subplot(2,1,1)
plt.plot(x,y)
plt.subplot(2,1,2)
plt.plot(x,z)

# %%
plt.subplot(121)
plt.plot(x,y)
plt.subplot(122)
plt.plot(x,z)

# %%
plt.figure(figsize=(16,9))
plt.title('My First Plot')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.plot(x,z,lw=5,marker='>',ms=20,mfc='y')
plt.savefig('myplot.png')

# %% [markdown]
# ### Scatter Plot

# %%
plt.title('My First Plot')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.scatter(x,y)

# %%
java=np.array([43,78,65,69,89,90,67,89,45,90])
python=np.array([34,56,67,78,79,89,90,89,98,80])
cols=[1,2,3,3,3,2,1,2,2,1]

# %%
plt.title('Result')
plt.xlabel('java marks')
plt.ylabel('Python marks')
plt.grid()
plt.scatter(java,python,c=cols)

# %% [markdown]
# ## Bar Plot

# %%
enrollment=[104,112,256,178,126,180]
courses=['C','Java','Python','R','PHP','JS']

# %%
plt.xlabel('courses')
plt.ylabel('Enrolled Students')
plt.grid()
plt.barh(courses,enrollment,color='brown')
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ## Pie chart

# %%
plt.figure(figsize=(10,10))
plt.pie(enrollment,labels=courses,autopct='%2.2f',shadow=True);

# %% [markdown]
# ### Univariable Analysis

# %% [markdown]
# ## Histogram

# %%
marks=np.array([67,56,45,61,93,72,65,58,65,49,68,62])

# %%
plt.title('Frequency plot for marks')
plt.xlabel('range of marks')
plt.ylabel('count')
plt.grid()
plt.xticks(range(0,101,10))
plt.hist(marks,bins=range(0,101,10),color='blue');
plt.savefig('myplot1.png')

# %% [markdown]
# ## Box Plot

# %%
plt.boxplot(marks);

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('salary_Data.csv')

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
plt.scatter(df['YearsExperience'],df['Salary'])

# %% [markdown]
# ## Separate the input and output data

# %%
x=df['YearsExperience'].values
y=df['Salary']

# %%
x
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
y;

# %%
x=x.reshape(30,1)

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %% [markdown]
#  ## import the regression class

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## create the object of linear regression

# %%
regressor=LinearRegression()

# %% [markdown]
# ## train the algorithm

# %%
regressor.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## predict on the unseen data

# %%
regressor.predict([[15]])
# Out:
# array([167541.63502049])

# %%
regressor.predict([[20]])
# Out:
# array([214791.44662777])

# %%
regressor
